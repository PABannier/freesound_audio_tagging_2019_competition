# %% [markdown]
# <h2>K-fold predictions</h2>

# %%
from fastai.vision import *
from fastai.callbacks import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedKFold

# %%
def _one_sample_positive_class_precisions(scores, truth):
    """Calculate precisions for each true class for a single sample.

    Args:
      scores: np.array of (num_classes,) giving the individual classifier scores.
      truth: np.array of (num_classes,) bools indicating which classes are true.

    Returns:
      pos_class_indices: np.array of indices of the true classes for this sample.
      pos_class_precisions: np.array of precisions corresponding to each of those
        classes.
    """
    num_classes = scores.shape[0]
    pos_class_indices = np.flatnonzero(truth > 0)
    # Only calculate precisions if there are some true classes.
    if not len(pos_class_indices):
        return pos_class_indices, np.zeros(0)
    # Retrieval list of classes for this sample.
    retrieved_classes = np.argsort(scores)[::-1]
    # class_rankings[top_scoring_class_index] == 0 etc.
    class_rankings = np.zeros(num_classes, dtype=np.int)
    class_rankings[retrieved_classes] = range(num_classes)
    # Which of these is a true label?
    retrieved_class_true = np.zeros(num_classes, dtype=np.bool)
    retrieved_class_true[class_rankings[pos_class_indices]] = True
    # Num hits for every truncated retrieval list.
    retrieved_cumulative_hits = np.cumsum(retrieved_class_true)
    # Precision of retrieval list truncated at each hit, in order of pos_labels.
    precision_at_hits = (
            retrieved_cumulative_hits[class_rankings[pos_class_indices]] /
            (1 + class_rankings[pos_class_indices].astype(np.float)))
    return pos_class_indices, precision_at_hits


def calculate_per_class_lwlrap(truth, scores):
    """Calculate label-weighted label-ranking average precision.

    Arguments:
      truth: np.array of (num_samples, num_classes) giving boolean ground-truth
        of presence of that class in that sample.
      scores: np.array of (num_samples, num_classes) giving the classifier-under-
        test's real-valued score for each class for each sample.

    Returns:
      per_class_lwlrap: np.array of (num_classes,) giving the lwlrap for each
        class.
      weight_per_class: np.array of (num_classes,) giving the prior of each
        class within the truth labels.  Then the overall unbalanced lwlrap is
        simply np.sum(per_class_lwlrap * weight_per_class)
    """
    assert truth.shape == scores.shape
    num_samples, num_classes = scores.shape
    # Space to store a distinct precision value for each class on each sample.
    # Only the classes that are true for each sample will be filled in.
    precisions_for_samples_by_classes = np.zeros((num_samples, num_classes))
    for sample_num in range(num_samples):
        pos_class_indices, precision_at_hits = (
            _one_sample_positive_class_precisions(scores[sample_num, :],
                                                  truth[sample_num, :]))
        precisions_for_samples_by_classes[sample_num, pos_class_indices] = (
            precision_at_hits)
    labels_per_class = np.sum(truth > 0, axis=0)
    weight_per_class = labels_per_class / float(np.sum(labels_per_class))
    # Form average of each column, i.e. all the precisions assigned to labels in
    # a particular class.
    per_class_lwlrap = (np.sum(precisions_for_samples_by_classes, axis=0) /
                        np.maximum(1, labels_per_class))
    # overall_lwlrap = simple average of all the actual per-class, per-sample precisions
    #                = np.sum(precisions_for_samples_by_classes) / np.sum(precisions_for_samples_by_classes > 0)
    #           also = weighted mean of per-class lwlraps, weighted by class label prior across samples
    #                = np.sum(per_class_lwlrap * weight_per_class)
    return per_class_lwlrap, weight_per_class

# %%
def lwlrap(y_pred,y_true):
    score, weight = calculate_per_class_lwlrap(y_true.cpu().numpy(), y_pred.cpu().numpy())
    lwlrap = (score * weight).sum()
    return torch.from_numpy(np.array(lwlrap))

# %%
class MixUpCallback(LearnerCallback):
    "Callback that creates the mixed-up input and target."
    def __init__(self, learn:Learner, alpha:float=0.4, stack_x:bool=False, stack_y:bool=True):
        super().__init__(learn)
        self.alpha,self.stack_x,self.stack_y = alpha,stack_x,stack_y
    
    def on_train_begin(self, **kwargs):
        if self.stack_y: self.learn.loss_func = MixUpLoss(self.learn.loss_func)
        
    def on_batch_begin(self, last_input, last_target, train, **kwargs):
        "Applies mixup to `last_input` and `last_target` if `train`."
        if not train: return
        lambd = np.random.beta(self.alpha, self.alpha, last_target.size(0))
        lambd = np.concatenate([lambd[:,None], 1-lambd[:,None]], 1).max(1)
        lambd = last_input.new(lambd)
        shuffle = torch.randperm(last_target.size(0)).to(last_input.device)
        x1, y1 = last_input[shuffle], last_target[shuffle]
        if self.stack_x:
            new_input = [last_input, last_input[shuffle], lambd]
        else: 
            new_input = (last_input * lambd.view(lambd.size(0),1,1,1) + x1 * (1-lambd).view(lambd.size(0),1,1,1))
        if self.stack_y:
            new_target = torch.cat([last_target[:,None].float(), y1[:,None].float(), lambd[:,None].float()], 1)
        else:
            if len(last_target.shape) == 2:
                lambd = lambd.unsqueeze(1).float()
            new_target = last_target.float() * lambd + y1.float() * (1-lambd)
        return {'last_input': new_input, 'last_target': new_target}  
    
    def on_train_end(self, **kwargs):
        if self.stack_y: self.learn.loss_func = self.learn.loss_func.get_old()
        

class MixUpLoss(nn.Module):
    "Adapt the loss function `crit` to go with mixup."
    
    def __init__(self, crit, reduction='mean'):
        super().__init__()
        if hasattr(crit, 'reduction'): 
            self.crit = crit
            self.old_red = crit.reduction
            setattr(self.crit, 'reduction', 'none')
        else: 
            self.crit = partial(crit, reduction='none')
            self.old_crit = crit
        self.reduction = reduction
        
    def forward(self, output, target):
        if len(target.size()) == 2:
            loss1, loss2 = self.crit(output,target[:,0].long()), self.crit(output,target[:,1].long())
            d = (loss1 * target[:,2] + loss2 * (1-target[:,2])).mean()
        else:  d = self.crit(output, target)
        if self.reduction == 'mean': return d.mean()
        elif self.reduction == 'sum':            return d.sum()
        return d
    
    def get_old(self):
        if hasattr(self, 'old_crit'):  return self.old_crit
        elif hasattr(self, 'old_red'): 
            setattr(self.crit, 'reduction', self.old_red)
            return self.crit

def mixup(learn:Learner, alpha:float=0.4, stack_x:bool=False, stack_y:bool=True) -> Learner:
    "Add mixup https://arxiv.org/abs/1710.09412 to `learn`."
    learn.callback_fns.append(partial(MixUpCallback, alpha=alpha, stack_x=stack_x, stack_y=stack_y))
    return learn
Learner.mixup = mixup

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(out_channels, out_channels, 3, 1, 1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

        self._init_weights()
        
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.zeros_(m.bias)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = F.avg_pool2d(x, 2)
        return x
    
class Classifier(nn.Module):
    def __init__(self, num_classes=1000): # <======== modificaition to comply fast.ai
        super().__init__()
        
        self.conv = nn.Sequential(
            ConvBlock(in_channels=3, out_channels=64),
            ConvBlock(in_channels=64, out_channels=128),
            ConvBlock(in_channels=128, out_channels=256),
            ConvBlock(in_channels=256, out_channels=512),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1)) # <======== modificaition to comply fast.ai
        self.fc = nn.Sequential(
            nn.Dropout(0.2),
            nn.Linear(512, 128),
            nn.PReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.1),
            nn.Linear(128, num_classes),
        )

    def forward(self, x):
        x = self.conv(x)
        #x = torch.mean(x, dim=3)   # <======== modificaition to comply fast.ai
        #x, _ = torch.max(x, dim=2) # <======== modificaition to comply fast.ai
        x = self.avgpool(x)         # <======== modificaition to comply fast.ai
        x = self.fc(x)
        return x

# %%
def borrowed_model(pretrained=False, **kwargs):
    return Classifier(**kwargs)

# %%
DATA = Path('freesound_audio_tagging')
PREPROCESSED = Path('fat2019')
WORK = Path('work')

CSV_TRN_CURATED = DATA/'train_curated.csv'
CSV_TRN_NOISY = DATA/'train_noisy.csv'
CSV_TRN_NOISY_BEST50S = PREPROCESSED/'trn_noisy_best50s.csv'
CSV_SUBMISSION = DATA/'sample_submission.csv'

MELS_TRN_CURATED = PREPROCESSED/'mels_train_curated.pkl'
MELS_TRN_NOISY = PREPROCESSED/'mels_train_noisy.pkl'
MELS_TRN_NOISY_BEST50S = PREPROCESSED/'mels_trn_noisy_best50s.pkl'
MELS_TEST = PREPROCESSED/'mels_test.pkl'

trn_curated_df = pd.read_csv(CSV_TRN_CURATED)
trn_noisy_df = pd.read_csv(CSV_TRN_NOISY)
trn_noisy50s_df = pd.read_csv(CSV_TRN_NOISY_BEST50S)
test_df = pd.read_csv(CSV_SUBMISSION)

# %%
X_train_curated = pickle.load(open(MELS_TRN_CURATED, 'rb'))
CUR_X_FILES, CUR_X = list(trn_curated_df.fname.values), X_train_curated

def open_fat2019_image(fn, convert_mode, after_open)->Image:
    # open
    idx = CUR_X_FILES.index(fn.split('/')[-1])
    x = PIL.Image.fromarray(CUR_X[idx])
    # crop 1sec
    time_dim, base_dim = x.size
    crop_x = random.randint(0, time_dim - base_dim)
    x = x.crop([crop_x, 0, crop_x+base_dim, base_dim])    
    # standardize
    return Image(pil2tensor(x, np.float32).div_(255))

vision.data.open_image = open_fat2019_image

# %%
SEED = 2000
BS = 128
SIZE = 128

# %%
tfms = get_transforms(do_flip=True, max_rotate=0, max_lighting=0.1, max_zoom=0, max_warp=0.)

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

# %%
acc_val = []
c = 1

for train_index, val_index in skf.split(trn_curated_df.index, trn_curated_df['labels']):
        
    src = (ImageList.from_csv(WORK, Path('..')/CSV_TRN_CURATED, folder='trn_curated')
          .split_by_idxs(train_index, val_index)
          .label_from_df(label_delim=',')
          )

    data_fold = (src.transform(tfms, size=SIZE)
            .databunch(bs=BS)
            .normalize(imagenet_stats)
           )
    
    learn = cnn_learner(data_fold, borrowed_model, pretrained=False, metrics=[lwlrap]).mixup(stack_y=False)
    learn.unfreeze()
    
    name = "cv_model_n" + str(c)
    print(name)
    cb = SaveModelCallback(learn, every='improvement', monitor='lwlrap', name=name)
    
    learn.fit_one_cycle(200, 3e-2, callbacks=cb)
    
    c += 1
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# cv_model_n1
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.719232</td>
#       <td>0.592169</td>
#       <td>0.095954</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.547657</td>
#       <td>0.264094</td>
#       <td>0.095756</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.339267</td>
#       <td>0.082830</td>
#       <td>0.115683</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.210375</td>
#       <td>0.071359</td>
#       <td>0.173506</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.146445</td>
#       <td>0.071230</td>
#       <td>0.174972</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.113210</td>
#       <td>0.068674</td>
#       <td>0.208555</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.095137</td>
#       <td>0.066133</td>
#       <td>0.247121</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.084608</td>
#       <td>0.066700</td>
#       <td>0.228543</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.077890</td>
#       <td>0.063706</td>
#       <td>0.266010</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.073726</td>
#       <td>0.064505</td>
#       <td>0.237144</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.070951</td>
#       <td>0.065421</td>
#       <td>0.239948</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.068912</td>
#       <td>0.067196</td>
#       <td>0.246452</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.067277</td>
#       <td>0.062036</td>
#       <td>0.285588</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.065527</td>
#       <td>0.061973</td>
#       <td>0.314112</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.064275</td>
#       <td>0.070980</td>
#       <td>0.296868</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.063007</td>
#       <td>0.053946</td>
#       <td>0.395781</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.061683</td>
#       <td>0.055649</td>
#       <td>0.420832</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.060394</td>
#       <td>0.052668</td>
#       <td>0.424131</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.059358</td>
#       <td>0.052234</td>
#       <td>0.446411</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.
# Better model found at epoch 16 with lwlrap value: 0.4208315896519141.
# Better model found at epoch 17 with lwlrap value: 0.42413072729280854.
# Better model found at epoch 18 with lwlrap value: 0.4464106396736901.
# Better model found at epoch 19 with lwlrap value: 0.5002928766651634.
# Better model found at epoch 23 with lwlrap value: 0.5570762109394206.
# Better model found at epoch 26 with lwlrap value: 0.6010931616412559.
# Better model found at epoch 33 with lwlrap value: 0.6336970210453101.
# Better model found at epoch 40 with lwlrap value: 0.6635351625194306.
# Better model found at epoch 53 with lwlrap value: 0.6688410173661108.
# Better model found at epoch 55 with lwlrap value: 0.6824838702984269.
# Better model found at epoch 61 with lwlrap value: 0.6939686627902768.
# Better model found at epoch 63 with lwlrap value: 0.7068642311566627.
# Better model found at epoch 73 with lwlrap value: 0.7105343315246823.
# Better model found at epoch 74 with lwlrap value: 0.7172431389068218.
# Better model found at epoch 77 with lwlrap value: 0.745362372788066.
# Better model found at epoch 81 with lwlrap value: 0.748351585295183.
# Better model found at epoch 94 with lwlrap value: 0.7819277665211434.
# Better model found at epoch 125 with lwlrap value: 0.7882817135932465.
# Better model found at epoch 129 with lwlrap value: 0.7943149354216584.
# Better model found at epoch 132 with lwlrap value: 0.7953530787094498.
# Better model found at epoch 136 with lwlrap value: 0.7993795016831189.
# Better model found at epoch 142 with lwlrap value: 0.8038066157190182.
# Better model found at epoch 148 with lwlrap value: 0.8093903653597546.
# Better model found at epoch 150 with lwlrap value: 0.8156504135187608.
# Better model found at epoch 164 with lwlrap value: 0.8175485771490112.
# Better model found at epoch 168 with lwlrap value: 0.8226596760391772.
# Better model found at epoch 178 with lwlrap value: 0.8250967248391788.
# Better model found at epoch 184 with lwlrap value: 0.8257001665502731.
# Better model found at epoch 188 with lwlrap value: 0.8288767246893011.
# Better model found at epoch 199 with lwlrap value: 0.8300657561645886.
# cv_model_n2
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.702049</td>
#       <td>0.524839</td>
#       <td>0.072961</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.521500</td>
#       <td>0.222207</td>
#       <td>0.097318</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.314970</td>
#       <td>0.078279</td>
#       <td>0.108814</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.195630</td>
#       <td>0.071728</td>
#       <td>0.169851</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.137422</td>
#       <td>0.070444</td>
#       <td>0.174351</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.107204</td>
#       <td>0.067301</td>
#       <td>0.250673</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.090867</td>
#       <td>0.066106</td>
#       <td>0.214101</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.081615</td>
#       <td>0.064491</td>
#       <td>0.241396</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.075942</td>
#       <td>0.064367</td>
#       <td>0.253047</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.072206</td>
#       <td>0.061460</td>
#       <td>0.312677</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.069323</td>
#       <td>0.066236</td>
#       <td>0.232562</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.067501</td>
#       <td>0.056339</td>
#       <td>0.383432</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.065811</td>
#       <td>0.056375</td>
#       <td>0.382725</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.064160</td>
#       <td>0.053439</td>
#       <td>0.406999</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.062728</td>
#       <td>0.059278</td>
#       <td>0.339155</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.061306</td>
#       <td>0.058088</td>
#       <td>0.372243</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.059976</td>
#       <td>0.054502</td>
#       <td>0.417850</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.058774</td>
#       <td>0.056193</td>
#       <td>0.378451</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.058109</td>
#       <td>0.051942</td>
#       <td>0.441682</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.056935</td>
#       <td>0.049034</td>
#       <td>0.495657</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0
# Better model found at epoch 18 with lwlrap value: 0.4416819179173996.
# Better model found at epoch 19 with lwlrap value: 0.49565747332142024.
# Better model found at epoch 22 with lwlrap value: 0.5199656703659993.
# Better model found at epoch 26 with lwlrap value: 0.5614409309237732.
# Better model found at epoch 27 with lwlrap value: 0.6262076611956585.
# Better model found at epoch 33 with lwlrap value: 0.6444492692324635.
# Better model found at epoch 42 with lwlrap value: 0.6539459546044656.
# Better model found at epoch 43 with lwlrap value: 0.6648662511292213.
# Better model found at epoch 46 with lwlrap value: 0.6831086428983905.
# Better model found at epoch 66 with lwlrap value: 0.6869942744751761.
# Better model found at epoch 67 with lwlrap value: 0.7240970436382973.
# Better model found at epoch 75 with lwlrap value: 0.729625243640591.
# Better model found at epoch 79 with lwlrap value: 0.7340718676234886.
# Better model found at epoch 82 with lwlrap value: 0.7434911164531981.
# Better model found at epoch 83 with lwlrap value: 0.7447131679298503.
# Better model found at epoch 84 with lwlrap value: 0.7496780167886881.
# Better model found at epoch 85 with lwlrap value: 0.7644409440164932.
# Better model found at epoch 93 with lwlrap value: 0.7684451882997235.
# Better model found at epoch 101 with lwlrap value: 0.7690596505619273.
# Better model found at epoch 102 with lwlrap value: 0.7807439409195533.
# Better model found at epoch 103 with lwlrap value: 0.7862090754273605.
# Better model found at epoch 121 with lwlrap value: 0.7905033175015128.
# Better model found at epoch 127 with lwlrap value: 0.8016595102394238.
# Better model found at epoch 132 with lwlrap value: 0.8023812557871227.
# Better model found at epoch 135 with lwlrap value: 0.8064442755472395.
# Better model found at epoch 136 with lwlrap value: 0.8069648291460431.
# Better model found at epoch 140 with lwlrap value: 0.8081272276766847.
# Better model found at epoch 147 with lwlrap value: 0.8096693692954198.
# Better model found at epoch 156 with lwlrap value: 0.8215779889864445.
# Better model found at epoch 164 with lwlrap value: 0.8244995818580847.
# Better model found at epoch 174 with lwlrap value: 0.8312972816324773.
# Better model found at epoch 184 with lwlrap value: 0.8335067777418942.
# Better model found at epoch 194 with lwlrap value: 0.8353052693142033.
# cv_model_n3
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.714035</td>
#       <td>0.571394</td>
#       <td>0.075796</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.533610</td>
#       <td>0.186545</td>
#       <td>0.085923</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.323378</td>
#       <td>0.084344</td>
#       <td>0.118925</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.200029</td>
#       <td>0.076009</td>
#       <td>0.158055</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.139757</td>
#       <td>0.073087</td>
#       <td>0.176107</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.108622</td>
#       <td>0.071356</td>
#       <td>0.212327</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.091979</td>
#       <td>0.070068</td>
#       <td>0.218460</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.082451</td>
#       <td>0.074657</td>
#       <td>0.201390</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.076624</td>
#       <td>0.070704</td>
#       <td>0.237913</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.072959</td>
#       <td>0.066554</td>
#       <td>0.252966</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.070513</td>
#       <td>0.064704</td>
#       <td>0.269988</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.068278</td>
#       <td>0.057837</td>
#       <td>0.368655</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.066570</td>
#       <td>0.058047</td>
#       <td>0.375558</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.064939</td>
#       <td>0.062299</td>
#       <td>0.312887</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.063713</td>
#       <td>0.054659</td>
#       <td>0.405501</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.062467</td>
#       <td>0.058009</td>
#       <td>0.350039</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.060968</td>
#       <td>0.059178</td>
#       <td>0.384413</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0
# Better model found at epoch 10 with lwlrap value: 0.269987875347379.
# Better model found at epoch 11 with lwlrap value: 0.36865540419227605.
# Better model found at epoch 12 with lwlrap value: 0.3755584386099416.
# Better model found at epoch 14 with lwlrap value: 0.4055014574379853.
# Better model found at epoch 17 with lwlrap value: 0.4162950082865245.
# Better model found at epoch 19 with lwlrap value: 0.5264518371267999.
# Better model found at epoch 27 with lwlrap value: 0.5517080238222025.
# Better model found at epoch 29 with lwlrap value: 0.5780003827655166.
# Better model found at epoch 40 with lwlrap value: 0.578360468446643.
# Better model found at epoch 41 with lwlrap value: 0.5851367681510214.
# Better model found at epoch 42 with lwlrap value: 0.5891764521903612.
# Better model found at epoch 45 with lwlrap value: 0.6266790769888756.
# Better model found at epoch 46 with lwlrap value: 0.6376713469491679.
# Better model found at epoch 48 with lwlrap value: 0.6426588856960228.
# Better model found at epoch 58 with lwlrap value: 0.6737126464285141.
# Better model found at epoch 62 with lwlrap value: 0.6871824285056496.
# Better model found at epoch 64 with lwlrap value: 0.6883721376909249.
# Better model found at epoch 68 with lwlrap value: 0.7096866006388474.
# Better model found at epoch 78 with lwlrap value: 0.7159368199842132.
# Better model found at epoch 86 with lwlrap value: 0.7269745815419021.
# Better model found at epoch 89 with lwlrap value: 0.7314034212051683.
# Better model found at epoch 95 with lwlrap value: 0.7355350250681363.
# Better model found at epoch 97 with lwlrap value: 0.7448798936651108.
# Better model found at epoch 98 with lwlrap value: 0.7573105070546701.
# Better model found at epoch 110 with lwlrap value: 0.7589181427636921.
# Better model found at epoch 112 with lwlrap value: 0.7713831794500654.
# Better model found at epoch 118 with lwlrap value: 0.7723704489739435.
# Better model found at epoch 119 with lwlrap value: 0.7749351232553394.
# Better model found at epoch 122 with lwlrap value: 0.7791342437181398.
# Better model found at epoch 123 with lwlrap value: 0.7804899717426089.
# Better model found at epoch 132 with lwlrap value: 0.7899201688411667.
# Better model found at epoch 135 with lwlrap value: 0.7918004464799953.
# Better model found at epoch 140 with lwlrap value: 0.799725205344275.
# Better model found at epoch 144 with lwlrap value: 0.8023892844614585.
# Better model found at epoch 146 with lwlrap value: 0.8042917614559338.
# Better model found at epoch 152 with lwlrap value: 0.8053579854697746.
# Better model found at epoch 162 with lwlrap value: 0.8197508336461017.
# Better model found at epoch 169 with lwlrap value: 0.8211553013217677.
# Better model found at epoch 187 with lwlrap value: 0.8215910214508841.
# Better model found at epoch 196 with lwlrap value: 0.8255325619111858.
# cv_model_n4
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.712179</td>
#       <td>1.350485</td>
#       <td>0.065176</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.534141</td>
#       <td>0.210797</td>
#       <td>0.100021</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.324649</td>
#       <td>0.082915</td>
#       <td>0.125996</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.201281</td>
#       <td>0.074394</td>
#       <td>0.153420</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.141002</td>
#       <td>0.075030</td>
#       <td>0.164207</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.109867</td>
#       <td>0.069729</td>
#       <td>0.190831</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.093194</td>
#       <td>0.067790</td>
#       <td>0.208517</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.083708</td>
#       <td>0.069109</td>
#       <td>0.243074</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.077981</td>
#       <td>0.066888</td>
#       <td>0.207488</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.074511</td>
#       <td>0.061880</td>
#       <td>0.301406</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0
td>
#       <td>00:
# Better model found at epoch 0 with lwlrap value: 0.06517577151579505.
# Better model found at epoch 1 with lwlrap value: 0.10002125570136638.
# Better model found at epoch 2 with lwlrap value: 0.12599566188276654.
# Better model found at epoch 3 with lwlrap value: 0.15342043210462886.
# Better model found at epoch 4 with lwlrap value: 0.16420711190576717.
# Better model found at epoch 5 with lwlrap value: 0.19083098928364983.
# Better model found at epoch 6 with lwlrap value: 0.2085168810355848.
# Better model found at epoch 7 with lwlrap value: 0.24307397624210558.
# Better model found at epoch 9 with lwlrap value: 0.30140605363298834.
# Better model found at epoch 12 with lwlrap value: 0.3342568158255553.
# Better model found at epoch 14 with lwlrap value: 0.3967760587683644.
# Better model found at epoch 15 with lwlrap value: 0.4131152931771111.
# Better model found at epoch 18 with lwlrap value: 0.504053678342411.
# Better model found at epoch 19 with lwlrap value: 0.5074070504019133.
# Better model found at epoch 21 with lwlrap value: 0.5650758112623453.
# Better model found at epoch 27 with lwlrap value: 0.5785590192036668.
# Better model found at epoch 29 with lwlrap value: 0.5852674267075769.
# Better model found at epoch 31 with lwlrap value: 0.5936712134139955.
# Better model found at epoch 32 with lwlrap value: 0.6000058196241809.
# Better model found at epoch 33 with lwlrap value: 0.6411447532764242.
# Better model found at epoch 38 with lwlrap value: 0.6516204036335251.
# Better model found at epoch 39 with lwlrap value: 0.6600776873385302.
# Better model found at epoch 51 with lwlrap value: 0.6800221876117271.
# Better model found at epoch 56 with lwlrap value: 0.7195032854147595.
# Better model found at epoch 74 with lwlrap value: 0.7204952565918933.
# Better model found at epoch 76 with lwlrap value: 0.727626518122474.
# Better model found at epoch 77 with lwlrap value: 0.7299978077106826.
# Better model found at epoch 84 with lwlrap value: 0.734604643784038.
# Better model found at epoch 93 with lwlrap value: 0.7367944512636823.
# Better model found at epoch 94 with lwlrap value: 0.7429903511887773.
# Better model found at epoch 96 with lwlrap value: 0.7446265146115534.
# Better model found at epoch 98 with lwlrap value: 0.7584998327391811.
# Better model found at epoch 101 with lwlrap value: 0.7667965565455004.
# Better model found at epoch 105 with lwlrap value: 0.776515447650424.
# Better model found at epoch 113 with lwlrap value: 0.7779536080018862.
# Better model found at epoch 116 with lwlrap value: 0.7850141272103115.
# Better model found at epoch 118 with lwlrap value: 0.7886261332343332.
# Better model found at epoch 120 with lwlrap value: 0.7930736203889582.
# Better model found at epoch 126 with lwlrap value: 0.7968801085980529.
# Better model found at epoch 135 with lwlrap value: 0.8085756769108576.
# Better model found at epoch 144 with lwlrap value: 0.8102727853275747.
# Better model found at epoch 152 with lwlrap value: 0.8112873105309621.
# Better model found at epoch 153 with lwlrap value: 0.8181352055769217.
# Better model found at epoch 171 with lwlrap value: 0.8250931585925478.
# Better model found at epoch 173 with lwlrap value: 0.8286121270381562.
# cv_model_n5
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>lwlrap</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.711174</td>
#       <td>0.658925</td>
#       <td>0.073569</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.538006</td>
#       <td>0.190936</td>
#       <td>0.085710</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.331020</td>
#       <td>0.090223</td>
#       <td>0.123571</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.205497</td>
#       <td>0.078467</td>
#       <td>0.138380</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.143091</td>
#       <td>0.078270</td>
#       <td>0.178642</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.110472</td>
#       <td>0.075209</td>
#       <td>0.209991</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0
td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.043649</td>
#       <td>0.057449</td>
#       <td>0.507388</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.043746</td>
#       <td>0.045095</td>
#       <td>0.592502</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.042916</td>
#       <td>0.043291</td>
#       <td>0.621206</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.043066</td>
#       <td>0.046246</td>
#       <td>0.623349</td>
#       <td>00:
# Better model found at epoch 0 with lwlrap value: 0.07356856303742917.
# Better model found at epoch 1 with lwlrap value: 0.08571031496301315.
# Better model found at epoch 2 with lwlrap value: 0.12357083912896422.
# Better model found at epoch 3 with lwlrap value: 0.13838003038839225.
# Better model found at epoch 4 with lwlrap value: 0.17864231149760262.
# Better model found at epoch 5 with lwlrap value: 0.20999086988542648.
# Better model found at epoch 7 with lwlrap value: 0.2553206814758026.
# Better model found at epoch 9 with lwlrap value: 0.2572709440367417.
# Better model found at epoch 10 with lwlrap value: 0.3053631860387906.
# Better model found at epoch 12 with lwlrap value: 0.3210335655123564.
# Better model found at epoch 13 with lwlrap value: 0.3235480297770296.
# Better model found at epoch 15 with lwlrap value: 0.3858498048197163.
# Better model found at epoch 17 with lwlrap value: 0.4565976425978235.
# Better model found at epoch 18 with lwlrap value: 0.4621287486920661.
# Better model found at epoch 19 with lwlrap value: 0.4817514814221456.
# Better model found at epoch 20 with lwlrap value: 0.4944706979973376.
# Better model found at epoch 21 with lwlrap value: 0.4980900554863655.
# Better model found at epoch 27 with lwlrap value: 0.5029601208244767.
# Better model found at epoch 28 with lwlrap value: 0.5059464603790479.
# Better model found at epoch 30 with lwlrap value: 0.536720629441867.
# Better model found at epoch 31 with lwlrap value: 0.5517655666122844.
# Better model found at epoch 33 with lwlrap value: 0.5681371489002506.
# Better model found at epoch 34 with lwlrap value: 0.5973090820604152.
# Better model found at epoch 46 with lwlrap value: 0.6098564563924007.
# Better model found at epoch 52 with lwlrap value: 0.6256953916277127.
# Better model found at epoch 62 with lwlrap value: 0.6368290563863467.
# Better model found at epoch 65 with lwlrap value: 0.6578551244072987.
# Better model found at epoch 66 with lwlrap value: 0.6726346909190428.
# Better model found at epoch 79 with lwlrap value: 0.680443300170748.
# Better model found at epoch 85 with lwlrap value: 0.693101436562574.
# Better model found at epoch 104 with lwlrap value: 0.7143455918317508.
# Better model found at epoch 109 with lwlrap value: 0.7217965951532279.
# Better model found at epoch 121 with lwlrap value: 0.7290508916860995.
# Better model found at epoch 127 with lwlrap value: 0.7366348979031977.
# Better model found at epoch 142 with lwlrap value: 0.7405159003557407.
# Better model found at epoch 143 with lwlrap value: 0.7471985106801459.
# Better model found at epoch 152 with lwlrap value: 0.7483948318338537.
# Better model found at epoch 153 with lwlrap value: 0.7485209054744035.
# Better model found at epoch 155 with lwlrap value: 0.748976021819966.
# Better model found at epoch 160 with lwlrap value: 0.756129164724422.
# Better model found at epoch 166 with lwlrap value: 0.7571717492470664.
# Better model found at epoch 168 with lwlrap value: 0.7628133890191686.
# Better model found at epoch 174 with lwlrap value: 0.7632472921948764.
# Better model found at epoch 175 with lwlrap value: 0.7675333290858606.
# Better model found at epoch 179 with lwlrap value: 0.7756046379734103.

# %% [markdown]
# <h2>Stacking generated model</h2>

# %%
learn.load("cv_model_n3")
learn.export()
